# %%
import requests
response=requests.get('https://rapidapi.com/dearthoirkami/api/the-legend-of-zelda')
print(response)
# Out:
# <Response [200]>

# %%
if response:
    print('Requets is successful.')
else:
    print('Request returned an error.')
# Out:
# Requets is successful.

# %%
import requests

limit=2
page=1
name="Hateno"
formats='text'
response=requests.get(f"https://rapidapi.com/dearthoirkami/api/the-legend-of-zelda/?{formats}&limit={limit}&page={page}&name={name}",
 headers={
     "X-RapidAPI-Host":"the-legend-of-zelda.p.rapidapi.com",
     "X-RapidAPI-Key":"0d97286a53msh727b75c018733a9p146cd0jsnded2112405b3"
 }
)
print(response.text)
# Out:
# <!DOCTYPE html><html lang="en" prefix="og: http://ogp.me/ns#"><head><style>
#               html {
#                 -webkit-font-smoothing: antialiased;
#                 -moz-osx-font-smoothing: grayscale;
#               }
#               html,
#               html * {
#                 font-family: Lato !important;
#               }
#               body {
#                 word-break: keep-all;
#               }
#               html pre code * {
#                 font-family: Consolas, Monaco, "Andale Mono", "Ubuntu Mono", monospace !important;
#               }
# ...

# %%
print(response.headers)
# Out:
# {'Date': 'Tue, 20 Apr 2021 14:07:54 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d8130c5b82025a4aeeb0568edcf29c8ea1618927673; expires=Thu, 20-May-21 14:07:53 GMT; path=/; domain=.rapidapi.com; HttpOnly; SameSite=Lax; Secure, locale=en-US; Max-Age=99999; Path=/; Expires=Wed, 21 Apr 2021 17:54:33 GMT, __variation__FFNewModalExperiment=0.04; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFPostSignupModalMarketplace=0.09; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFNewHero=0.48; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFNewOrgCreatePage=0.57; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFAskCompanyInfo=0.96; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFEmbedTeamsVideo=0.98; Max-A
# ...

# %%
if response.status_code==200:
    content=response.content
    print(content)
# Out:
# b'<!DOCTYPE html><html lang="en" prefix="og: http://ogp.me/ns#"><head><style>\n              html {\n                -webkit-font-smoothing: antialiased;\n                -moz-osx-font-smoothing: grayscale;\n              }\n              html,\n              html * {\n                font-family: Lato !important;\n              }\n              body {\n                word-break: keep-all;\n              } \n              html pre code * {\n                font-family: Consolas, Monaco, "Andale Mono", "Ubuntu Mono", monospace !important;\n              }            \n            </style><script>window.__RAPID_FLAGS__={"flags":{"FFMartketplaceAllowRenderCreateOrgButtonInHeader":{"value":true,"condition":null,"description":"Allow rendering the Create organization button on the marketplace main header. ","created":"2019-09-11T16:23:15.632Z","key":"FFMartketplaceAllowRenderCreateOrgButtonInHeader","type":"conditional"},"FFPDAllowHardLimitMP":{"key":"FFPDAllowHardLimitMP","value":true,"c
# ...

# %%
import json
data=response.text
print('DATA:',repr(data))

data_string=json.dumps(data)
print('JSON:',data_string)
# Out:
# DATA: '<!DOCTYPE html><html lang="en" prefix="og: http://ogp.me/ns#"><head><style>\n              html {\n                -webkit-font-smoothing: antialiased;\n                -moz-osx-font-smoothing: grayscale;\n              }\n              html,\n              html * {\n                font-family: Lato !important;\n              }\n              body {\n                word-break: keep-all;\n              } \n              html pre code * {\n                font-family: Consolas, Monaco, "Andale Mono", "Ubuntu Mono", monospace !important;\n              }            \n            </style><script>window.__RAPID_FLAGS__={"flags":{"FFMartketplaceAllowRenderCreateOrgButtonInHeader":{"value":true,"condition":null,"description":"Allow rendering the Create organization button on the marketplace main header. ","created":"2019-09-11T16:23:15.632Z","key":"FFMartketplaceAllowRenderCreateOrgButtonInHeader","type":"conditional"},"FFPDAllowHardLimitMP":{"key":"FFPDAllowHardLimitMP","value":tr
# ...

# %%
import json

data=response.text
data_string=json.dumps(data)
print('ENCODED:',data_string)

decoded=json.loads(data_string)
print('ENCODED:',decoded)
# Out:
# ENCODED: "<!DOCTYPE html><html lang=\"en\" prefix=\"og: http://ogp.me/ns#\"><head><style>\n              html {\n                -webkit-font-smoothing: antialiased;\n                -moz-osx-font-smoothing: grayscale;\n              }\n              html,\n              html * {\n                font-family: Lato !important;\n              }\n              body {\n                word-break: keep-all;\n              } \n              html pre code * {\n                font-family: Consolas, Monaco, \"Andale Mono\", \"Ubuntu Mono\", monospace !important;\n              }            \n            </style><script>window.__RAPID_FLAGS__={\"flags\":{\"FFMartketplaceAllowRenderCreateOrgButtonInHeader\":{\"value\":true,\"condition\":null,\"description\":\"Allow rendering the Create organization button on the marketplace main header. \",\"created\":\"2019-09-11T16:23:15.632Z\",\"key\":\"FFMartketplaceAllowRenderCreateOrgButtonInHeader\",\"type\":\"conditional\"},\"FFPDAllowHardLimitMP\":{\"
# ...

# %%
print(response.headers)
# Out:
# {'Date': 'Tue, 20 Apr 2021 14:07:54 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d8130c5b82025a4aeeb0568edcf29c8ea1618927673; expires=Thu, 20-May-21 14:07:53 GMT; path=/; domain=.rapidapi.com; HttpOnly; SameSite=Lax; Secure, locale=en-US; Max-Age=99999; Path=/; Expires=Wed, 21 Apr 2021 17:54:33 GMT, __variation__FFNewModalExperiment=0.04; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFPostSignupModalMarketplace=0.09; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFNewHero=0.48; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFNewOrgCreatePage=0.57; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFAskCompanyInfo=0.96; Max-Age=31536000; Path=/; Expires=Wed, 20 Apr 2022 14:07:53 GMT; HttpOnly, __variation__FFEmbedTeamsVideo=0.98; Max-A
# ...

# %%
headers = {"X-Request-Id": "<my-request-id>"}
response = requests.get("https://example.org", headers=headers)
response.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'X-Request-Id': '<my-request-id>'}

# %%
response = requests.get("https://rapidapi.com/dearthoirkami/api/the-legend-of-zelda")
response.headers.get("Content-Type")
# Out:
# 'text/html; charset=utf-8'
