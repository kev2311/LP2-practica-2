# %%
# Importando las librerías
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests

# %%
# Mercado libre - laptops
# Accediendo al website
url="https://listado.mercadolibre.com.pe/computacion/laptops/"
uclient=urlopen(url)
pagehtml=uclient.read()
uclient.close()
pagesoup=soup(pagehtml, "html.parser")
c=pagesoup.findAll("li",{"class":"ui-search-layout__item"})
c[1].div.a["title"]
# Out:
# 'Laptop Lenovo Ideapad S540 Intel Core I5 10ma Gen 8gb 512gb '

# %%
titulos=[]
precio_actual=[]
descuento=[]
precio_anterior=[]
detalles=[]

#find busca un elemento
#findAll crea una lista

for i in range(0,4):
    url="https://listado.mercadolibre.com.pe/computacion/laptops/"+"_Desde_"+str(i*50+1)
    uclient=urlopen(url)
    pagehtml=uclient.read()
    uclient.close()
    pagesoup=soup(pagehtml, "html.parser")
    c=pagesoup.findAll("li",{"class":"ui-search-layout__item"})

    for i in range(0,len(c)):
        
        titulo=c[i].div.a["title"]
        #mas especifico
        titulo=c[i].find("div",{"ui-search-item__group ui-search-item__group--title"}).a["title"] #[0] ya que guarda todo en una lista de un elemento y agarramos ese element                titulos.append(titulo)
        titulos.append(titulo)
        if len(c[i].findAll("span",{"price-tag-fraction"})) == 2:
            
            precioactual=c[i].findAll("span",{"price-tag-fraction"})[1].text
            precioanterior=c[i].findAll("span",{"price-tag-fraction"})[0].text
            descuento1=c[i].find("span",{"class":"ui-search-price__discount"}).text
            precio_actual.append(precioactual)
            precio_anterior.append(precioanterior)
            descuento.append(descuento1)

        elif len(c[i].findAll("span",{"price-tag-fraction"})) == 1:
            descuento1=0
            descuento.append(descuento1)
            precioactual=c[i].findAll("span",{"price-tag-fraction"})[0].text
            precioanterior=c[i].findAll("span",{"price-tag-fraction"})[0].text
            precio_actual.append(precioactual)
            precio_anterior.append(precioanterior)


        detalles1=c[i].findAll("div",{"class":"ui-search-item__group ui-search-item__group--details"})
        if detalles1==[]:
            detalles1="na"
            detalles.append(detalles1)
        else:
            detalles1=detalles1[0].text
            detalles.append(detalles1)
            
for i in range(0,len(precio_actual)):
    precio_actual[i]=float(precio_actual[i].replace(".",""))
    precio_anterior[i]=float(precio_anterior[i].replace(".",""))

# %%
# Visualizando la data con formato Json
data ={"Nombre":titulos,"Detalles":detalles,"Precio actual":precio_actual,"Precio anterior":precio_anterior
                 ,"Descuento":descuento}
#Nos devuelve el String con el JSON
data_string = json.dumps(data)
print ('JSON:', data_string)
# Out:
# JSON: {"Nombre": ["Laptop Lenovo Ideapad S540 Intel Core I7 10ma Generaci\u00f3n", "Laptop Lenovo Ideapad S540 Intel Core I5 10ma Gen 8gb 512gb ", "Laptop Lenovo Legion 15.6 I7ma 16gb 1tbssd Rtx2060 Super6gb", "Laptop Hp 250 G7 Core I7-1065g7 8gb/1tb/2v/15.6' Freedos", "Laptop Lenovo Legion 7 Intel Core I7 10ma Gen Cuotas Sin Int", "Laptop Lenovo Legion 5 Amd Ryzen 5 8gb Rtx 2060", "Laptop Lenovo Thinkpad\u00a0l13 Yoga Intel Core I5 + Combo", "Nuevo Hp 14 Fhd Intel 10th Gen I3 1005g1 3.4ghz 
ebook...", "Laptop Profesional Dell Precision M4800-4910mq 3d/cad Corei7", "Laptop Asus X512da Ryzen5 3500u 15.6  12gb 128 Ssd+ 1tb Hdd", "Laptop Apple Macbook Pro 13  M1 Z11f-myda-06 512gb Late 2020", "Laptop Advance Barata Intel 4gb Ssd Escolares Office Zoom ", "Lenovo Laptop Amd A6 Series 64gb Platinum Grey Nuevo Env\u00ed...", "Nuevo Asus 15.6 C523na Ih44f Chromebook 15.6 Intel Celero...", "Laptop Macbook Air Retina 2020 13.3 I5 256gb|ssd 8gb Ram!!", "Asus Zephyrus G14 Ryzen 9 14.0' Fhd 16gb 1tb Ssd Rtx2060 6gb", "Chuwi Gemibook Pro 14 2k 16g+512gb Ssd Ultrabook Matebook D", "Sellado Hp 15.6 Hd Intel N6045u 4gb 128gb Ssd Rojo Escarl...", "Laptop/tablet 2 En 1 Hp Revolve 810 Core I5. 8gb. Ssd. Touch", "Ultrabook Lenovo Thinkpad Ci7 5ta Gen 12gb 1 Tb Full Hd 14 ", "Laptop Core I5 8va Hp Dell Lenovo Asus Acer Toshiba 14 PuLG.", "Tornillos Para Pcs...envios A Provincia, Pack 100u,", "Laptop Huawei Matebook D14 Modelo Ryzen 7 Ram 8gb 512gb 2021", "A Estrenar Hp Stream 14 Hd Intel N4000 4gb Ram 64gb 14 Cb...", " Macbook Air 2020 Core I3 256gb 8gb Nuevo Garantia 5 Tiendas", "Chuwi Herobook Pro Laptop Windows 10 Intel 14.1 Notebook...", "Laptop Teclast F6 Plus 8gb 13.3 Touch Screen Convertible 360", "Ultrabook Lenovo Thinkpa ...

# %%
#Creando Data Frame
df=pd.DataFrame({"Nombre":titulos,"Detalles":detalles,"Precio actual":precio_actual,"Precio anterior":precio_anterior
                 ,"Descuento":descuento},index=list(range(1,len(titulos)+1))) 

#Pasando lo datos a un csv
df.to_csv("laptops.csv")

# %%
df   #Visualizando la dataframe
# Out:
#                                                 Nombre Detalles  \
# 1    Laptop Lenovo Ideapad S540 Intel Core I7 10ma ...       na
# 2    Laptop Lenovo Ideapad S540 Intel Core I5 10ma ...       na
# 3    Laptop Lenovo Legion 15.6 I7ma 16gb 1tbssd Rtx...       na
# 4    Laptop Hp 250 G7 Core I7-1065g7 8gb/1tb/2v/15....       na
# 5    Laptop Lenovo Legion 7 Intel Core I7 10ma Gen ...       na
# ..                                                 ...      ...
# 196  Gamer Alienware M17 R3 Con 17'3 Pulgadas Windo...       na
# 197  Case Fintie Para Macbook Pro 13 2019 A1706 A17...       na
# 198  Laptop Microsoft 15 Surface Book 3 I7ma 512gb ...       na
# 199  Laptop Compaq Presario V3718la - 14.1  Amd Ath...    Usado
# 200                            Dumps Bios De Laptops .       na
#
#      Precio actual  Precio anterior Descuento
# 1           3599.0           3599.0         0
# 2           2959.0           2959.0         0
# 3           7199.0           7199.0         0
# 4           3500.0           3500.0         0
# 5           8999.0           8999.0         0
# ..             ...              ...       ...
# 196         2657.0           2657.0         0
# 197          135.0            135.0         0
# 198         2500.0           2500.0         0
# 199          100.0            100.0         0
# 200           25.0             25.0         0
#
# [200 rows x 5 columns]
